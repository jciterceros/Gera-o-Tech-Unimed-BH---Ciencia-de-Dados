# %% [markdown]
# Analise de dados Python com Jupyter Notebook

# %%
# Comentario em Python

# %%
frase = "Python para analise de dados"

# %%
frase[0]
# Out:
# 'P'

# %%
frase[0:10]
# Out:
# 'Python par'

# %%
frase.count('a')
# Out:
# 5

# %%
frase.lower()
# Out:
# 'python para analise de dados'

# %%
frase.upper()
# Out:
# 'PYTHON PARA ANALISE DE DADOS'

# %%
frase.replace('Python','Frases')
# Out:
# 'Frases para analise de dados'

# %%
frase = frase.upper()

# %%
frase
# Out:
# 'PYTHON PARA ANALISE DE DADOS'

# %% [markdown]
# Estruturas de dados

# %%
# Listas
animais = [1,2,3]
animais
# Out:
# [1, 2, 3]

# %%
animais = ["cahorro","gato",12345,6.5]
animais
# Out:
# ['cahorro', 'gato', 12345, 6.5]

# %%
animais[3]
# Out:
# 6.5

# %%
animais[0]= "Periquito"
animais
# Out:
# ['Periquito', 'gato', 12345, 6.5]

# %%
animais.remove('gato')
animais
# Out:
# ['Periquito', 12345, 6.5]

# %%
len(animais)
# Out:
# 3

# %%
"gato" in animais
# Out:
# False

# %%
"Periquito"  in animais
# Out:
# True

# %%
lista = [500,30,300,80,10]

# %%
max(lista)
# Out:
# 500

# %%
min(lista)
# Out:
# 10

# %%
lista.append(800)
lista
# Out:
# [500, 30, 300, 80, 10, 800]

# %%
lista.extend([900,2])
lista
# Out:
# [500, 30, 300, 80, 10, 800, 900, 2]

# %%
lista.sort()
lista
# Out:
# [2, 10, 30, 80, 300, 500, 800, 900]

# %%
indice = lista.index(30,0,len(lista))
indice
# Out:
# 2

# %%
lista[indice]
# Out:
# 30

# %% [markdown]
# Tuplas

# %%
tp = ("Banana","Maca", 10, 50)
tp
# Out:
# ('Banana', 'Maca', 10, 50)

# %%
tp[0]
# Out:
# 'Banana'

# %% [markdown]
# Dicionarios

# %%
dc = {"Maca":20,"Banana":10,"Laranja":15,"Uva":5}
dc
# Out:
# {'Maca': 20, 'Banana': 10, 'Laranja': 15, 'Uva': 5}

# %%
dc["Maca"]
# Out:
# 20

# %%
dc.keys()
# Out:
# dict_keys(['Maca', 'Banana', 'Laranja', 'Uva'])

# %%
dc.values()
# Out:
# dict_values([20, 10, 15, 5])

# %%
# caso Pera nao exista ele adiciona "Pera":22
dc.setdefault("Pera",22)
dc
# Out:
# {'Maca': 20, 'Banana': 10, 'Laranja': 15, 'Uva': 5, 'Pera': 22}
